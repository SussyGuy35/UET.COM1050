# %% [markdown]
# # W5A1

# %%
def Max_Of_Two(a, b):
    return a if a > b else b

# %% [markdown]
# # W5A2

# %%
def swap(a, b):
    return (b, a)

# %% [markdown]
# # W5A3

# %%
def eratosthenes(n):
    is_prime = [True] * (n + 1)
    is_prime[0] = is_prime[1] = False 
    for i in range(2, int(n**0.5) + 1):
        if is_prime[i]:
            for j in range(i * i, n + 1, i):
                is_prime[j] = False
    return is_prime

so_nguyen_to = eratosthenes(10000000)

def is_prime(num):
    return so_nguyen_to[num]

# %% [markdown]
# # W5A4

# %%
import math
n = int(input())

def is_perfect_number(n):
    sum_divisors = 0
    for i in range(1, int(math.sqrt(n)) + 1):
        if n % i == 0:
            sum_divisors += i
    return sum_divisors == n

# %% [markdown]
# # W5A5

# %%
def find_k_in_list(k, list):
    for i in range(len(list)):
        if list[i] == k:
            return i
    return -1

# %% [markdown]
# # W5A6

# %%
def factorial(n):
    if n == 1:
        return 1
    return n * factorial(n - 1)

# %% [markdown]
# # W5A7

# %%
def calculator(a, b, op):
    match op:
        case '+':
            return a + b
        case '-':
            return a - b
        case '*':
            return a * b
        case '/':
            return a / b

# %% [markdown]
# # W5A8

# %%
def hamming_distance(a,b):
    return (a^b).bit_count()

# %% [markdown]
# # W5A9

# %%
def sum_of_digits(n):
    if n == 0:
        return 0
    return n % 10 + sum_of_digits(n // 10)
